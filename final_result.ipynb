# %%
from comparing import extract_data
import Bagging, SVM, Stacking
import pandas as pd
import warnings as wr

wr.filterwarnings('ignore')

data = extract_data()

# %%
Bagging.learn_best_params(data)

# %%
SVM.learn_best_params(data)

# %%
Stacking.learn_best_params(data)
# Out:
# En İyi Stacking Skoru: 0.8373545449363031
# En İyi Stacking Parametreleri: {'meta_C': 9.91136061063686, 'passthrough': False}
