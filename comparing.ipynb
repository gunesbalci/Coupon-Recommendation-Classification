# %%
from comparing import *
import pandas as pd

X_train, X_test, y_train, y_test = extract_data()
X_train_no_time = X_train.drop(columns=['time'])
X_test_no_time = X_test.drop(columns=['time'])
X_train_no_gender = X_train.drop(columns=['gender'])
X_test_no_gender = X_test.drop(columns=['gender'])
X_train_no_direction = X_train.drop(columns=['direction_opp'])
X_test_no_direction = X_test.drop(columns=['direction_opp'])
X_train_no_target, X_test_no_target, y_train, y_test = extract_data(False)

lr_auc = train("Logistic Regression",X_train, X_test, y_train, y_test, True)
lr_auc_no_time = train("Logistic Regression",X_train_no_time, X_test_no_time, y_train, y_test, False)
lr_auc_no_gender = train("Logistic Regression",X_train_no_gender, X_test_no_gender, y_train, y_test, False)
lr_auc_no_direction = train("Logistic Regression",X_train_no_direction, X_test_no_direction, y_train, y_test, False)
lr_auc_no_target = train("Logistic Regression",X_train_no_target, X_test_no_target, y_train, y_test, False)
print(f"Logistic Regression ROC-AUC: {lr_auc}\nno time column: {lr_auc_no_time}\nno gender column: {lr_auc_no_gender}")
print(f"no direction column: {lr_auc_no_direction}\nNo target encoding: {lr_auc_no_target}")
# Out:
# Accuracy: 0.689928628072958
#
# Detaylı Sınıflandırma Raporu:
#                precision    recall  f1-score   support
#
#            0       0.66      0.59      0.62      1091
#            1       0.71      0.76      0.74      1431
#
#     accuracy                           0.69      2522
#    macro avg       0.68      0.68      0.68      2522
# weighted avg       0.69      0.69      0.69      2522
#
# Confusion Matrix:
#  [[ 649  442]
#  [ 340 1091]]
# ROC-AUC Skoru: 0.7418
# Logistic Regression ROC-AUC: 0.7418485275306955
# no time column: 0.741346356473555
# no gender column: 0.7411260161117483
# no direction column: 0.741785756148553
# No target encoding: 0.74234173124753

# %%
rf_auc = train("RandomForest",X_train, X_test, y_train, y_test, True)
rf_auc_no_time = train("RandomForest",X_train_no_time, X_test_no_time, y_train, y_test, False)
rf_auc_no_gender = train("RandomForest",X_train_no_gender, X_test_no_gender, y_train, y_test, False)
rf_auc_no_direction = train("RandomForest",X_train_no_direction, X_test_no_direction, y_train, y_test, False)
rf_auc_no_target = train("RandomForest",X_train_no_target, X_test_no_target, y_train, y_test, False)
print(f"Random Forest ROC-AUC: {rf_auc}\nno time column: {rf_auc_no_time}\nno gender column: {rf_auc_no_gender}")
print(f"no direction column: {rf_auc_no_direction}\nNo target encoding: {rf_auc_no_target}")
# Out:
# Accuracy: 0.7220459952418715
#
# Detaylı Sınıflandırma Raporu:
#                precision    recall  f1-score   support
#
#            0       0.70      0.63      0.66      1091
#            1       0.74      0.79      0.76      1431
#
#     accuracy                           0.72      2522
#    macro avg       0.72      0.71      0.71      2522
# weighted avg       0.72      0.72      0.72      2522
#
# Confusion Matrix:
#  [[ 687  404]
#  [ 297 1134]]
# ROC-AUC Skoru: 0.7857
# Random Forest ROC-AUC: 0.7856741614415895
# no time column: 0.7867137323927875
# no gender column: 0.7791974999055227
# no direction column: 0.7906369437766978
# No target encoding: 0.7967834150322086

# %%
svm_auc = train("Support Vector Machine",X_train, X_test, y_train, y_test, True)
svm_auc_no_time = train("Support Vector Machine",X_train_no_time, X_test_no_time, y_train, y_test, False)
svm_auc_no_gender = train("Support Vector Machine",X_train_no_gender, X_test_no_gender, y_train, y_test, False)
svm_auc_no_direction = train("Support Vector Machine",X_train_no_direction, X_test_no_direction, y_train, y_test, False)
svm_auc_no_target = train("Support Vector Machine",X_train_no_target, X_test_no_target, y_train, y_test, False)
print(f"Support Vector Machine ROC-AUC: {svm_auc}\nno time column: {svm_auc_no_time}\nno gender column: {svm_auc_no_gender}")
print(f"no direction column: {svm_auc_no_direction}\nNo target encoding: {svm_auc_no_target}")
# Out:
# Accuracy: 0.7212529738302934
#
# Detaylı Sınıflandırma Raporu:
#                precision    recall  f1-score   support
#
#            0       0.70      0.63      0.66      1091
#            1       0.74      0.79      0.76      1431
#
#     accuracy                           0.72      2522
#    macro avg       0.72      0.71      0.71      2522
# weighted avg       0.72      0.72      0.72      2522
#
# Confusion Matrix:
#  [[ 685  406]
#  [ 297 1134]]
# ROC-AUC Skoru: 0.7776
# Support Vector Machine ROC-AUC: 0.7776109211956539
# no time column: 0.7757316228772224
# no gender column: 0.7738138931003362
# no direction column: 0.7801121686167429
# No target encoding: 0.786338705410701

# %%
xgb_auc = train("XGBoost",X_train, X_test, y_train, y_test, True)
xgb_auc_no_time = train("XGBoost",X_train_no_time, X_test_no_time, y_train, y_test, False)
xgb_auc_no_gender = train("XGBoost",X_train_no_gender, X_test_no_gender, y_train, y_test, False)
xgb_auc_no_direction = train("XGBoost",X_train_no_direction, X_test_no_direction, y_train, y_test, False)
xgb_auc_no_target = train("XGBoost",X_train_no_target, X_test_no_target, y_train, y_test, False)
print(f"XGBoost ROC-AUC: {xgb_auc}\nno time column: {xgb_auc_no_time}\nno gender column: {xgb_auc_no_gender}")
print(f"no direction column: {xgb_auc_no_direction}\nNo target encoding: {xgb_auc_no_target}")
# Out:
# Accuracy: 0.746629659000793
#
# Detaylı Sınıflandırma Raporu:
#                precision    recall  f1-score   support
#
#            0       0.74      0.64      0.69      1091
#            1       0.75      0.83      0.79      1431
#
#     accuracy                           0.75      2522
#    macro avg       0.75      0.73      0.74      2522
# weighted avg       0.75      0.75      0.74      2522
#
# Confusion Matrix:
#  [[ 697  394]
#  [ 245 1186]]
# ROC-AUC Skoru: 0.8152
# XGBoost ROC-AUC: 0.8152289137796634
# no time column: 0.8133457723153865
# no gender column: 0.8138588322857556
# no direction column: 0.8171562514211632
# No target encoding: 0.8114741602886459

# %%
adaB_auc = train("XAdaBoost",X_train, X_test, y_train, y_test, True)
adaB_auc_no_time = train("XAdaBoost",X_train_no_time, X_test_no_time, y_train, y_test, False)
adaB_auc_no_gender = train("XAdaBoost",X_train_no_gender, X_test_no_gender, y_train, y_test, False)
adaB_auc_no_direction = train("XAdaBoost",X_train_no_direction, X_test_no_direction, y_train, y_test, False)
adaB_auc_no_target = train("XAdaBoost",X_train_no_target, X_test_no_target, y_train, y_test, False)
print(f"AdaBoost ROC-AUC: {adaB_auc}\nno time column: {adaB_auc_no_time}\nno gender column: {adaB_auc_no_gender}")
print(f"no direction column: {adaB_auc_no_direction}\nNo target encoding: {adaB_auc_no_target}")
# Out:
# Accuracy: 0.6946867565424266
#
# Detaylı Sınıflandırma Raporu:
#                precision    recall  f1-score   support
#
#            0       0.73      0.47      0.57      1091
#            1       0.68      0.87      0.76      1431
#
#     accuracy                           0.69      2522
#    macro avg       0.70      0.67      0.67      2522
# weighted avg       0.70      0.69      0.68      2522
#
# Confusion Matrix:
#  [[ 513  578]
#  [ 192 1239]]
# ROC-AUC Skoru: 0.7479
# AdaBoost ROC-AUC: 0.7479248613745269
# no time column: 0.7479248613745269
# no gender column: 0.7479248613745269
# no direction column: 0.7479248613745269
# No target encoding: 0.7471459838165129

# %%
LGBM_auc = train("LightGBM",X_train, X_test, y_train, y_test, True)
LGBM_auc_no_time = train("LightGBM",X_train_no_time, X_test_no_time, y_train, y_test, False)
LGBM_auc_no_gender = train("LightGBM",X_train_no_gender, X_test_no_gender, y_train, y_test, False)
LGBM_auc_no_direction = train("LightGBM",X_train_no_direction, X_test_no_direction, y_train, y_test, False)
LGBM_auc_no_target = train("LightGBM",X_train_no_target, X_test_no_target, y_train, y_test, False)
print(f"AdaBoost ROC-AUC: {LGBM_auc}\nno time column: {LGBM_auc_no_time}\nno gender column: {LGBM_auc_no_gender}")
print(f"no direction column: {LGBM_auc_no_direction}\nNo target encoding: {LGBM_auc_no_target}")
# Out:
# Accuracy: 0.7577319587628866
#
# Detaylı Sınıflandırma Raporu:
#                precision    recall  f1-score   support
#
#            0       0.75      0.66      0.70      1091
#            1       0.76      0.83      0.80      1431
#
#     accuracy                           0.76      2522
#    macro avg       0.76      0.75      0.75      2522
# weighted avg       0.76      0.76      0.76      2522
#
# Confusion Matrix:
#  [[ 725  366]
#  [ 245 1186]]
# ROC-AUC Skoru: 0.8149
# AdaBoost ROC-AUC: 0.8149297889280249
# no time column: 0.8121082793531473
# no gender column: 0.8075906614118054
# no direction column: 0.8182630774246568
# No target encoding: 0.8103199354863917

# %%
CB_auc = train("CatBoost",X_train, X_test, y_train, y_test, True)
CB_auc_no_time = train("CatBoost",X_train_no_time, X_test_no_time, y_train, y_test, False)
CB_auc_no_gender = train("CatBoost",X_train_no_gender, X_test_no_gender, y_train, y_test, False)
CB_auc_no_direction = train("CatBoost",X_train_no_direction, X_test_no_direction, y_train, y_test, False)
CB_auc_no_target = train("CatBoost",X_train_no_target, X_test_no_target, y_train, y_test, False)
print(f"CatBoost ROC-AUC: {CB_auc}\nno time column: {CB_auc_no_time}\nno gender column: {CB_auc_no_gender}")
print(f"no direction column: {CB_auc_no_direction}\nNo target encoding: {CB_auc_no_target}")
# Out:
# Accuracy: 0.7418715305313244
#
# Detaylı Sınıflandırma Raporu:
#                precision    recall  f1-score   support
#
#            0       0.74      0.63      0.68      1091
#            1       0.74      0.83      0.79      1431
#
#     accuracy                           0.74      2522
#    macro avg       0.74      0.73      0.73      2522
# weighted avg       0.74      0.74      0.74      2522
#
# Confusion Matrix:
#  [[ 682  409]
#  [ 242 1189]]
# ROC-AUC Skoru: 0.8037
# CatBoost ROC-AUC: 0.8036655284549722
# no time column: 0.8005455345527636
# no gender column: 0.7989941846798115
# no direction column: 0.7993656887782064
# No target encoding: 0.8008766856197809

# %%
ET_auc = train("ExtraTrees",X_train, X_test, y_train, y_test, True)
ET_auc_no_time = train("ExtraTrees",X_train_no_time, X_test_no_time, y_train, y_test, False)
ET_auc_no_gender = train("ExtraTrees",X_train_no_gender, X_test_no_gender, y_train, y_test, False)
ET_auc_no_direction = train("ExtraTrees",X_train_no_direction, X_test_no_direction, y_train, y_test, False)
ET_auc_no_target = train("ExtraTrees",X_train_no_target, X_test_no_target, y_train, y_test, False)
print(f"ExtraTrees ROC-AUC: {ET_auc}\nno time column: {ET_auc_no_time}\nno gender column: {ET_auc_no_gender}")
print(f"no direction column: {ET_auc_no_direction}\nNo target encoding: {ET_auc_no_target}")
# Out:
# Accuracy: 0.6931007137192704
#
# Detaylı Sınıflandırma Raporu:
#                precision    recall  f1-score   support
#
#            0       0.65      0.62      0.64      1091
#            1       0.72      0.75      0.73      1431
#
#     accuracy                           0.69      2522
#    macro avg       0.69      0.68      0.69      2522
# weighted avg       0.69      0.69      0.69      2522
#
# Confusion Matrix:
#  [[ 676  415]
#  [ 359 1072]]
# ROC-AUC Skoru: 0.7489
# ExtraTrees ROC-AUC: 0.7488689942038955
# no time column: 0.7510115480127413
# no gender column: 0.7443350428927102
# no direction column: 0.7534724424024529
# No target encoding: 0.7722301967498515

# %%
HGB_auc = train("HistGradientBoosting",X_train, X_test, y_train, y_test, True)
HGB_auc_no_time = train("HistGradientBoosting",X_train_no_time, X_test_no_time, y_train, y_test, False)
HGB_auc_no_gender = train("HistGradientBoosting",X_train_no_gender, X_test_no_gender, y_train, y_test, False)
HGB_auc_no_direction = train("HistGradientBoosting",X_train_no_direction, X_test_no_direction, y_train, y_test, False)
HGB_auc_no_target = train("HistGradientBoosting",X_train_no_target, X_test_no_target, y_train, y_test, False)
print(f"HistGradientBoosting ROC-AUC: {HGB_auc}\nno time column: {HGB_auc_no_time}\nno gender column: {HGB_auc_no_gender}")
print(f"no direction column: {HGB_auc_no_direction}\nNo target encoding: {HGB_auc_no_target}")
# Out:
# Accuracy: 0.746233148295004
#
# Detaylı Sınıflandırma Raporu:
#                precision    recall  f1-score   support
#
#            0       0.73      0.65      0.69      1091
#            1       0.75      0.82      0.79      1431
#
#     accuracy                           0.75      2522
#    macro avg       0.74      0.73      0.74      2522
# weighted avg       0.75      0.75      0.74      2522
#
# Confusion Matrix:
#  [[ 706  385]
#  [ 255 1176]]
# ROC-AUC Skoru: 0.8065
# HistGradientBoosting ROC-AUC: 0.8065209858181512
# no time column: 0.8016190532922629
# no gender column: 0.8063695018194093
# no direction column: 0.8073991446438396
# No target encoding: 0.8079327013920515

# %%
bagging_auc = train("Bagging",X_train, X_test, y_train, y_test, True)
bagging_auc_no_time = train("Bagging",X_train_no_time, X_test_no_time, y_train, y_test, False)
bagging_auc_no_gender = train("Bagging",X_train_no_gender, X_test_no_gender, y_train, y_test, False)
bagging_auc_no_direction = train("Bagging",X_train_no_direction, X_test_no_direction, y_train, y_test, False)
bagging_auc_no_target = train("Bagging",X_train_no_target, X_test_no_target, y_train, y_test, False)
print(f"Bagging ROC-AUC: {bagging_auc}\nno time column: {bagging_auc_no_time}\nno gender column: {bagging_auc_no_gender}")
print(f"no direction column: {bagging_auc_no_direction}\nNo target encoding: {bagging_auc_no_target}")
# Out:
# Accuracy: 0.7442505947660587
#
# Detaylı Sınıflandırma Raporu:
#                precision    recall  f1-score   support
#
#            0       0.73      0.66      0.69      1091
#            1       0.76      0.81      0.78      1431
#
#     accuracy                           0.74      2522
#    macro avg       0.74      0.73      0.74      2522
# weighted avg       0.74      0.74      0.74      2522
#
# Confusion Matrix:
#  [[ 717  374]
#  [ 271 1160]]
# ROC-AUC Skoru: 0.8079
# Bagging ROC-AUC: 0.8078901065255977
# no time column: 0.8079080412062097
# no gender column: 0.801409601843685
# no direction column: 0.8089447297980235
# No target encoding: 0.8109002505090566

# %%
stacking_auc = train("Stacking",X_train, X_test, y_train, y_test, True)
stacking_auc_no_time = train("Stacking",X_train_no_time, X_test_no_time, y_train, y_test, False)
stacking_auc_no_gender = train("Stacking",X_train_no_gender, X_test_no_gender, y_train, y_test, False)
stacking_auc_no_direction = train("Stacking",X_train_no_direction, X_test_no_direction, y_train, y_test, False)
stacking_auc_no_target = train("Stacking",X_train_no_target, X_test_no_target, y_train, y_test, False)
print(f"Stacking ROC-AUC: {stacking_auc}\nno time column: {stacking_auc_no_time}\nno gender column: {stacking_auc_no_gender}")
print(f"no direction column: {stacking_auc_no_direction}\nNo target encoding: {stacking_auc_no_target}")
# Out:
# Accuracy: 0.76050753370341
#
# Detaylı Sınıflandırma Raporu:
#                precision    recall  f1-score   support
#
#            0       0.75      0.67      0.71      1091
#            1       0.77      0.83      0.80      1431
#
#     accuracy                           0.76      2522
#    macro avg       0.76      0.75      0.75      2522
# weighted avg       0.76      0.76      0.76      2522
#
# Confusion Matrix:
#  [[ 730  361]
#  [ 243 1188]]
# ROC-AUC Skoru: 0.8239
# Stacking ROC-AUC: 0.8238567762027287
# no time column: 0.822438014861445
# no gender column: 0.816679701336326
# no direction column: 0.8265380109542467
# No target encoding: 0.8222529033365552

# %%
voting_auc = train("Voting",X_train, X_test, y_train, y_test, True)
voting_auc_no_time = train("Voting",X_train_no_time, X_test_no_time, y_train, y_test, False)
voting_auc_no_gender = train("Voting",X_train_no_gender, X_test_no_gender, y_train, y_test, False)
voting_auc_no_direction = train("Voting",X_train_no_direction, X_test_no_direction, y_train, y_test, False)
voting_auc_no_target = train("Voting",X_train_no_target, X_test_no_target, y_train, y_test, False)
print(f"Voting ROC-AUC: {voting_auc}\nno time column: {voting_auc_no_time}\nno gender column: {voting_auc_no_gender}")
print(f"no direction column: {voting_auc_no_direction}\nNo target encoding: {voting_auc_no_target}")
# Out:
# Accuracy: 0.7498017446471055
#
# Detaylı Sınıflandırma Raporu:
#                precision    recall  f1-score   support
#
#            0       0.74      0.65      0.69      1091
#            1       0.75      0.83      0.79      1431
#
#     accuracy                           0.75      2522
#    macro avg       0.75      0.74      0.74      2522
# weighted avg       0.75      0.75      0.75      2522
#
# Confusion Matrix:
#  [[ 705  386]
#  [ 245 1186]]
# ROC-AUC Skoru: 0.8157
# Voting ROC-AUC: 0.8157291632638812
# no time column: 0.8125899536324455
# no gender column: 0.8125335874933786
# no direction column: 0.8177743573779753
# No target encoding: 0.8130171833455995

# %%
results_data = {
    "Plain": [lr_auc, rf_auc, svm_auc, xgb_auc, adaB_auc, LGBM_auc, CB_auc, ET_auc, HGB_auc, bagging_auc, stacking_auc, voting_auc],
    "Time Rmv": [lr_auc_no_time, rf_auc_no_time, svm_auc_no_time, xgb_auc_no_time, adaB_auc_no_time, LGBM_auc_no_time, CB_auc_no_time, ET_auc_no_time, HGB_auc_no_time, bagging_auc_no_time, stacking_auc_no_time, voting_auc_no_time],
    "Gender Rmv": [lr_auc_no_gender, rf_auc_no_gender, svm_auc_no_gender, xgb_auc_no_gender, adaB_auc_no_gender, LGBM_auc_no_gender, CB_auc_no_gender, ET_auc_no_gender, HGB_auc_no_gender, bagging_auc_no_gender, stacking_auc_no_gender, voting_auc_no_gender],
    "Direction Rmv": [lr_auc_no_direction, rf_auc_no_direction, svm_auc_no_direction, xgb_auc_no_direction, adaB_auc_no_direction, LGBM_auc_no_direction, CB_auc_no_direction, ET_auc_no_direction, HGB_auc_no_direction, bagging_auc_no_direction, stacking_auc_no_direction, voting_auc_no_direction],
    "Target Enc Rmv": [lr_auc_no_target, rf_auc_no_target, svm_auc_no_target, xgb_auc_no_target, adaB_auc_no_target, LGBM_auc_no_target, CB_auc_no_target, ET_auc_no_target, HGB_auc_no_target, bagging_auc_no_target, stacking_auc_no_target, voting_auc_no_target],
}

create_heatmap(results_data)
